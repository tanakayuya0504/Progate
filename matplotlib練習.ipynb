# %%
import matplotlib.pyplot as plt
# Out:
# Duplicate key in file WindowsPath('C:/Users/yuyat/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/matplotlib/mpl-data/matplotlibrc'), line 263 ('font.family:  MS Gothic')
# Duplicate key in file WindowsPath('C:/Users/yuyat/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/matplotlib/mpl-data/matplotlibrc'), line 275 (' font.serif      : Noto Serif CJK JP, DejaVu Serif, Bitstream Vera Serif, New Century Schoolbook, Century Schoolbook L, Utopia, ITC Bookman, Bookman, Nimbus Roman No9 L, Times New Roman, Times, Palatino, Charter, serif')
# ...

# %%
x = ["月", "火", "水", "木", "金", "土", "日"]
# x = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
y = [10, 40, 50, 10, 20, 90, 10]
plt.bar(x, y)
plt.show()

# %%
import matplotlib as mpl
mpl.matplotlib_fname()
# Out:
# 'C:\\Users\\yuyat\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %%
mpl.font_manager.findSystemFonts()
# Out:
# ['C:\\Windows\\Fonts\\CENTURY.TTF',
#  'C:\\Windows\\Fonts\\segoeuii.ttf',
#  'C:\\Windows\\Fonts\\BASKVILL.TTF',
#  'C:\\Windows\\Fonts\\impact.ttf',
#  'C:\\Windows\\Fonts\\LTYPEO.TTF',
#  'C:\\Windows\\Fonts\\HGRSMP.TTF',
#  'C:\\Windows\\Fonts\\HGRKK.TTC',
#  'C:\\Windows\\Fonts\\TCBI____.TTF',
#  'C:\\Windows\\Fonts\\BRLNSR.TTF',
#  'C:\\Windows\\Fonts\\GILC____.TTF',
#  'C:\\Windows\\Fonts\\HTOWERT.TTF',
#  'C:\\Windows\\Fonts\\PERB____.TTF',
#  'C:\\Windows\\Fonts\\constani.ttf',
#  'C:\\Windows\\Fonts\\trebucit.ttf',
#  'C:\\Windows\\Fonts\\SCHLBKBI.TTF',
#  'C:\\Windows\\Fonts\\BSSYM7.TTF',
#  'C:\\Windows\\Fonts\\BELLB.TTF',
#  'C:\\Windows\\Fonts\\monbaiti.ttf',
#  'C:\\Windows\\Fonts\\malgunsl.ttf',
#  'C:\\Windows\\Fonts\\segoeuib.ttf',
#  'C:\\Windows\\Fonts\\DUBAI-BOLD.TTF',
#  'C:\\Windows\\Fonts\\GILSANUB.TTF',
#  'C:\\Windows\\Fonts\\segoeuil.ttf',
#  'C:\\Windows\\Fonts\\HGRGM.TTC',
#  'C:\\Windows\\Fonts\\comicz.ttf',
#  'C:\\Windows\\Fonts\\ROCCB___.TTF',
# ...
